# %% [markdown]
# ## Training File
# Do not run this file unless necessary. This will train a new model saved as *saved_model/model-11.h5*.

# %%
import tensorflow 

import pandas as pd
import numpy as np
import os
import keras
import random
import cv2
import math
import seaborn as sns

from sklearn.metrics import confusion_matrix
from sklearn.preprocessing import LabelBinarizer
from sklearn.model_selection import train_test_split

import matplotlib.pyplot as plt

from tensorflow.keras.layers import Dense,GlobalAveragePooling2D,Convolution2D,BatchNormalization
from tensorflow.keras.layers import Flatten,MaxPooling2D,Dropout

from tensorflow.keras.applications import DenseNet121
from tensorflow.keras.applications.densenet import preprocess_input

from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator,img_to_array

from tensorflow.keras.models import Model

from tensorflow.keras.optimizers import Adam

from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau

import warnings
warnings.filterwarnings("ignore")

# %%
print("Tensorflow-version:", tensorflow.__version__)
# Out:
# Tensorflow-version: 2.3.0

# %%
model_d=DenseNet121(weights='imagenet',include_top=False, input_shape=(128, 128, 3)) 

x=model_d.output

x= GlobalAveragePooling2D()(x)
x= BatchNormalization()(x)
x= Dropout(0.5)(x)
x= Dense(1024,activation='relu')(x) 
x= Dense(512,activation='relu')(x) 
x= BatchNormalization()(x)
x= Dropout(0.5)(x)

preds=Dense(1,activation='sigmoid')(x) #FC-layer

# %%
model=Model(inputs=model_d.input,outputs=preds)
model.summary()

# %%
for layer in model.layers[:-1]:
    layer.trainable=False
    
for layer in model.layers[-1:]:
    layer.trainable=True

# %%
model.compile(optimizer='Adam',loss='binary_crossentropy',metrics=['accuracy'])
model.summary()

# %%
data=[]
labels=[]
random.seed(42)
imagePaths = sorted(list(os.listdir("data/Infection")))
random.shuffle(imagePaths)
print(imagePaths)

for img in imagePaths:
    path=sorted(list(os.listdir("data/infection/"+img)))
    for i in path:
        image = cv2.imread("data/infection/"+img+'/'+i)
        image = cv2.resize(image, (128,128))
        image = img_to_array(image)
        data.append(image)
        l = label = img
        labels.append(l)
# Out:
# ['Aug-Positive', 'Aug-Negative']

# %%
data = np.array(data, dtype="float32") / 255.0
labels = np.array(labels)
mlb = LabelBinarizer()
labels = mlb.fit_transform(labels)
print(labels[0])
# Out:
# [1]

# %%
(xtrain,xtest,ytrain,ytest)=train_test_split(data,labels,test_size=0.4,random_state=42)
print(xtrain.shape, xtest.shape)
# Out:
# (3528, 128, 128, 3) (2353, 128, 128, 3)

# %%
anne = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5, patience=5, verbose=1, min_lr=1e-3)
checkpoint = ModelCheckpoint('model.h5', verbose=1, save_best_only=True)

datagen = ImageDataGenerator(zoom_range = 0.2, horizontal_flip=True, shear_range=0.2)


datagen.fit(xtrain)
# Fits-the-model
history = model.fit_generator(datagen.flow(xtrain, ytrain, batch_size=32),
               steps_per_epoch=xtrain.shape[0] // 32,
               epochs=11,
               verbose=1,
               callbacks=[anne, checkpoint],
               validation_data=(xtrain, ytrain))
# Out:
# Epoch 1/11
# 110/110 [==============================] - ETA: 0s - loss: 0.6616 - accuracy: 0.6267
# Epoch 00001: val_loss improved from inf to 0.62197, saving model to model.h5
# 110/110 [==============================] - 343s 3s/step - loss: 0.6616 - accuracy: 0.6267 - val_loss: 0.6220 - val_accuracy: 0.6630
# Epoch 2/11
# 110/110 [==============================] - ETA: 0s - loss: 0.6449 - accuracy: 0.6276
# Epoch 00002: val_loss improved from 0.62197 to 0.61675, saving model to model.h5
# 110/110 [==============================] - 336s 3s/step - loss: 0.6449 - accuracy: 0.6276 - val_loss: 0.6168 - val_accuracy: 0.6695
# Epoch 3/11
# 110/110 [==============================] - ETA: 0s - loss: 0.6508 - accuracy: 0.6244
# Epoch 00003: val_loss improved from 0.61675 to 0.61650, saving model to model.h5
# 110/110 [==============================] - 332s 3s/step - loss: 0.6508 - accuracy: 0.6244 - val_loss: 0.6165 - val_accuracy: 0.6678
# Epoch 4/11
# 110/110 [==============================] - ETA: 0s - loss: 0.6508 - accuracy: 0.6259
# Epoch 00004: val_loss improved from 0.61650 to 0.61479, saving model to model.h5
# 110/110 [==============================] - 326s 3s/step - loss: 0.6508 - accuracy: 0.6259 - val_loss: 0.6148 - val_accuracy: 0.6701
# Epoch 5/11
# 110/110 [==============================] - ETA: 0s - loss: 0.6556 - accuracy: 0.6281
# Epoch 00005: val_loss did not improve from 0.61479
# 110/110 [==============================] - 336s 3s/step - loss: 0.6556 - accuracy: 0.6281 - val_loss: 0.6157 - val_accuracy: 0.6667
# Epoch 6/11
# 110/110 [==============================] - ETA: 0s - loss: 0.6453 - accuracy: 0.6239
# Epoch 00006: val_loss did not improve from 0.61479
# 110/110 [==============================] - 324s 3s/step - loss: 0.6453 - accuracy: 0.6239 - val_loss: 0.6152 - val_accuracy: 0.6729
# Epoch 7/11
# 110/110 [==============================] - ETA: 0s - loss: 0.6475 - accuracy: 0.6193
# Epoch 00007: val_loss improved from 0.61479 to 0.61249, saving model to model.h5
# 110/110 [==============================] - 333s 3s/step - loss: 0.6475 - accuracy: 0.6193 - val_loss: 0.6125 - val_accuracy: 0.6732
# Epoch 8/11
# 110/110 [==============================] - ETA: 0s - loss: 0.6484 - accuracy: 0.6316
# Epoch 00008: val_loss did not improve from 0.61249
# 110/110 [==============================] - 327s 3s/step - loss: 0.6484 - accuracy: 0.6316 - val_loss: 0.6166 - val_accuracy: 0.6729
# Epoch 9/11
# 110/110 [==============================] - ETA: 0s - loss: 0.6487 - accuracy: 0.6293
# Epoch 00009: val_loss did not improve from 0.61249
# 110/110 [==============================] - 321s 3s/step - loss: 0.6487 - accuracy: 0.6293 - val_loss: 0.6131 - val_accuracy: 0.6766
# Epoch 10/11
# 110/110 [==============================] - ETA: 0s - loss: 0.6553 - accuracy: 0.6259
# Epoch 00010: val_loss did not improve from 0.61249
# 110/110 [==============================] - 327s 3s/step - loss: 0.6553 - accuracy: 0.6259 - val_loss: 0.6136 - val_accuracy: 0.6760
# Epoch 11/11
# 110/110 [==============================] - ETA: 0s - loss: 0.6447 - accuracy: 0.6290
# Epoch 00011: val_loss did not improve from 0.61249
# 110/110 [==============================] - 378s 3s/step - loss: 0.6447 - accuracy: 0.6290 - val_loss: 0.6158 - val_accuracy: 0.6723

# %%
ypred = model.predict(xtest)

total = 0
accurate = 0
accurateindex = []
wrongindex = []

print(ytest[0])
print(ypred[0])
for i in range(len(ypred)):
    if np.round(ypred[i]) == ytest[i]:
        accurate += 1
        accurateindex.append(i)
    else:
        wrongindex.append(i)
        
    total += 1
    
print('Total-test-data;', total, '\taccurately-predicted-data:', accurate, '\t wrongly-predicted-data: ', total - accurate)
print('Accuracy:', round(accurate/total*100, 3), '%')
# Out:
# [0]
# [0.3917842]
# Total-test-data; 2353 	accurately-predicted-data: 1528 	 wrongly-predicted-data:  825
# Accuracy: 64.938 %

# %%
label=['infected', 'not infected']
imidx = random.sample(accurateindex, k=9)# replace with 'wrongindex'

nrows = 3
ncols = 3
fig, ax = plt.subplots(nrows,ncols,sharex=True,sharey=True,figsize=(15, 12))

n = 0
for row in range(nrows):
    for col in range(ncols):
            ax[row,col].imshow(xtest[imidx[n]], cmap="viridis")
            ax[row,col].set_title("Predicted label :{}\nTrue label :{}".format(label[np.argmax(ypred[imidx[n]])], label[np.argmax(ytest[imidx[n]])]))
            n += 1

plt.show()

# %%
Ypred = model.predict(xtest)

Ypred = np.round(Ypred)
Ytrue = np.round(ytest)

cm = confusion_matrix(Ytrue, Ypred)
plt.figure(figsize=(12, 12))
ax = sns.heatmap(cm, cmap="rocket_r", fmt=".01f",annot_kws={'size':16}, annot=True, square=True, xticklabels=label, yticklabels=label)
ax.set_ylabel('Actual', fontsize=20)
ax.set_xlabel('Predicted', fontsize=20)
# Out:
# Text(0.5, 145.31999999999996, 'Predicted')

# %%
model.save('saved_model/model-11.h5')
model.save_weights('saved_model/model-11-weights.h5')
